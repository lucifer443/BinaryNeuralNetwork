# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('/workspace/S/jiangfei/BinaryNeuralNetwork_debug')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from features import Features

# %%
configs = '/workspace/S/jiangfei/BinaryNeuralNetwork_debug/configs/baseline/rprelu_group/react_a/adreact_a_gprelu-0.7_scb_s516_step1.py'
ckpt = '/workspace/S/jiangfei/BinaryNeuralNetwork_debug/work_dirs/rprelu/react_a/adreact_baseline-1.2_step1/epoch_70.pth'
fea = Features(configs,ckpt)
# Out:
# Use load_from_local loader

# %%
fea.save_features('/workspace/S/jiangfei/BinaryNeuralNetwork_debug/demo/demo.JPEG')
# Out:
# RAconv: 31

# %%
pp = fea.RAconv_in
import matplotlib.pyplot as plt
import math
import numpy as np
ncols = 8
nrows = math.ceil(31 / ncols)
fig, axs = plt.subplots(nrows, ncols, figsize=(ncols * 4, nrows * 3))
index = 0
for ax, feas in zip(axs.flat, fea.RAconv_in):
    ax.hist(feas.flatten().numpy(), bins=100,range=(-5,5))
    #ax.hist(feas.flatten().sign().numpy(), bins=10,range=(-2,2))
    ax.set_title(f'conv_{index} ')
    ax.grid()
    index += 1

plt.savefig(f'/workspace/S/jiangfei/BinaryNeuralNetwork_debug/tools/plot/bias_figure/figure/adm-1.2_70pch.jpg')
