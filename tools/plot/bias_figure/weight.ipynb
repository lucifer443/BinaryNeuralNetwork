# %%
# %load_ext autoreload
# %autoreload 2
import sys
import torch
sys.path.append('/workspace/S/jiangfei/BinaryNeuralNetwork_debug')

# %%
models = torch.load('/workspace/S/jiangfei/BinaryNeuralNetwork_debug/work_dirs/rprelu/react_a/adreact_baseline-1.1_step1/latest.pth')
models = models["state_dict"]
w=[]
for name,weight in models.items():
    # if 'binary' in name:
    #     w.append(weight)
    if 'weight' in name:
        w.append(weight)

print(w[10])
# Out:
# tensor([ 2.8167,  4.2293,  4.6920,  0.4824,  1.5235,  1.0003,  1.5916,  0.6792,
#          0.4940,  1.8534,  1.9349, -0.0574,  1.4349,  0.2534,  1.6405,  1.6165,
#          0.4264,  1.2136,  0.0185,  1.0568,  0.8459,  0.7556,  1.8062,  0.9945,
#          0.6300,  3.3299,  1.9586,  0.3940,  2.6111,  1.1142,  0.0292,  0.2866,
#          0.5039, -0.5392,  0.4318,  1.0793,  0.4828,  0.5822,  1.0885,  0.3559,
#          0.2740,  1.0685,  0.8985,  0.3209,  0.3808,  1.4468,  0.3986,  1.3416,
#          2.2927,  0.6536,  2.4923,  1.1236,  2.4924, -0.2374,  1.7398,  0.1946,
#          1.7770,  0.9973,  1.2193, -0.4621,  2.0914,  3.9244,  0.2057,  0.5434])

# %%
models = torch.load('/workspace/S/jiangfei/BinaryNeuralNetwork_debug/work_dirs/rprelu/react_a1/adreact_af75_fl_lb/epoch_45.pth')
w=[]
models = models["state_dict"]

for name,weight in models.items():
    # if 'binary' in name:
    #     w.append(weight)
    if 'rebias' in name:
        print(weight)
        w.append(weight)


import matplotlib.pyplot as plt
import math
import numpy as np
ncols = 8
nrows = math.ceil(26 / ncols)
fig, axs = plt.subplots(nrows, ncols, figsize=(ncols * 4, nrows * 3))
index = 0

for ax, feas in zip(axs.flat, w):
    ax.hist(feas.flatten().numpy(), bins=20)
    #ax.hist(feas.flatten().sign().numpy(), bins=10,range=(-2,2))
    ax.set_title(f'conv_{index} ')
    ax.grid()
    index += 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_37780/1078281817.py in <module>
# ----> 1 models = torch.load('/workspace/S/jiangfei/BinaryNeuralNetwork_debug/work_dirs/rprelu/react_a1/adreact_af75_fl_lb/epoch_75.pth')
#       2 w=[]
#       3 models = models["state_dict"]
#       4
#       5 for name,weight in models.items():
#
# /workspace/S/jiangfei/softwares/anaconda3/envs/binarya100/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     577         pickle_load_args['encoding'] = 'utf-8'
#     578
# --> 579     with _open_file_like(f, 'rb') as opened_file:
#     580         if _is_zipfile(opened_file):
#     581             # The zipfile reader is going to advance the current file position.
#
# /workspace/S/jiangfei/softwares/anaconda3/envs/binarya100/lib/python3.7/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# /workspace/S/jiangfei/softwares/anaconda3/envs/binarya100/lib/python3.7/site-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/S/jiangfei/BinaryNeuralNetwork_debug/work_dirs/rprelu/react_a1/adreact_af75_fl_lb/epoch_75.pth'

# %%
models = torch.load('/workspace/S/jiangfei/BinaryNeuralNetwork_debug/work_dirs/rprelu/react_a/adreact_rprelu_step1/latest.pth')
w=[]
models = models["state_dict"]

for name,weight in models.items():
    # if 'binary' in name:
    #     w.append(weight)
    if 'move' in name:
        w.append(weight)

import matplotlib.pyplot as plt
import math
import numpy as np
ncols = 8
nrows = math.ceil(26 / ncols)
fig, axs = plt.subplots(nrows, ncols, figsize=(ncols * 4, nrows * 3))
index = 0

for ax, feas in zip(axs.flat, w):
    ax.hist(feas.flatten().numpy(), bins=20)
    #ax.hist(feas.flatten().sign().numpy(), bins=10,range=(-2,2))
    ax.set_title(f'conv_{index} ')
    ax.grid()
    index += 1
