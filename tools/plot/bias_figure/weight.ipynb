# %%
# %load_ext autoreload
# %autoreload 2
import sys
import torch
sys.path.append('/workspace/S/jiangfei/BinaryNeuralNetwork_debug')

# %%
models = torch.load('/workspace/S/jiangfei/BinaryNeuralNetwork_debug/work_dirs/rprelu/react_a1/adreact_lb_0fe-5_step1/latest.pth')
w=[]
models = models["state_dict"]

for name,weight in models.items():
    # if 'binary' in name:
    #     w.append(weight)
    if 'adbias' in name:
        w.append(weight)

# %%
import matplotlib.pyplot as plt
import math
import numpy as np
ncols = 8
nrows = math.ceil(26 / ncols)
fig, axs = plt.subplots(nrows, ncols, figsize=(ncols * 4, nrows * 3))
index = 0

for ax, feas in zip(axs.flat, w):
    ax.hist(feas.flatten().numpy(), bins=20)
    #ax.hist(feas.flatten().sign().numpy(), bins=10,range=(-2,2))
    ax.set_title(f'conv_{index} ')
    ax.grid()
    index += 1

# %%
models = torch.load('/workspace/S/jiangfei/BinaryNeuralNetwork_debug/work_dirs/rprelu/react_a1/adreact_lb_0fe-4_step1/epoch_10.pth')
w=[]
models = models["state_dict"]

for name,weight in models.items():
    # if 'binary' in name:
    #     w.append(weight)
    if 'adbias' in name:
        w.append(weight)

import matplotlib.pyplot as plt
import math
import numpy as np
ncols = 8
nrows = math.ceil(26 / ncols)
fig, axs = plt.subplots(nrows, ncols, figsize=(ncols * 4, nrows * 3))
index = 0

for ax, feas in zip(axs.flat, w):
    ax.hist(feas.flatten().numpy(), bins=20)
    #ax.hist(feas.flatten().sign().numpy(), bins=10,range=(-2,2))
    ax.set_title(f'conv_{index} ')
    ax.grid()
    index += 1
